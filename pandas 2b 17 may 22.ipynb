# %%
import pandas as pd 
import numpy as np

# %%
# !gdown 1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# To: C:\Users\Acer\movies.csv
#
#   0%|          | 0.00/112k [00:00<?, ?B/s]
# 100%|##########| 112k/112k [00:00<00:00, 1.79MB/s]

# %%
# !gdown 1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# To: C:\Users\Acer\directors.csv
#
#   0%|          | 0.00/65.4k [00:00<?, ?B/s]
# 100%|##########| 65.4k/65.4k [00:00<00:00, 1.04MB/s]

# %%
movies = pd.read_csv("movies.csv")
movies.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# ...

# %%
directors = pd.read_csv("directors.csv")
directors.head()
# Out:
#    Unnamed: 0      director_name    id gender
# 0           0      James Cameron  4762   Male
# 1           1     Gore Verbinski  4763   Male
# 2           2         Sam Mendes  4764   Male
# 3           3  Christopher Nolan  4765   Male
# 4           4     Andrew Stanton  4766   Male

# %%
movies = pd.read_csv('movies.csv' , index_col = 0)
movies
# Out:
#          id     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 5     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 4736  48363          0           3      321952
# 4743  48370      27000          19     3151130
# 4748  48375          0           7           0
# 4749  48376          0           3           0
# 4768  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
directors = pd.read_csv('directors.csv' , index_col = 0)
directors
# Out:
#           director_name    id gender
# 0         James Cameron  4762   Male
# 1        Gore Verbinski  4763   Male
# 2            Sam Mendes  4764   Male
# 3     Christopher Nolan  4765   Male
# 4        Andrew Stanton  4766   Male
# ...                 ...   ...    ...
# 2344      Shane Carruth  7106   Male
# 2345   Neill Dela Llana  7107    NaN
# 2346        Scott Smith  7108    NaN
# 2347        Daniel Hsia  7109   Male
# 2348   Brian Herzlinger  7110   Male
#
# [2349 rows x 3 columns]

# %%
data = movies.merge(directors,how = 'left' , left_on = 'director_id' , right_on = 'id')

# %%
data.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day      director_name  id_y gender
# 0         4762  2009   Dec  Thursday      James Cameron  4762   Male
# 1         4763  2007   May  Saturday     Gore Verbinski  4763   Male
# ...

# %%
data.drop(['director_id', 'id_y'] , axis = 1 , inplace = True)

# %%
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
data['revenue'] = data['revenue']/1000000

# %%
data['budget'] = data['budget']/1000000

# %%
data
# Out:
#        id_x   budget  popularity      revenue  \
# 0     43597  237.000         150  2787.965087
# 1     43598  300.000         139   961.000000
# 2     43599  245.000         107   880.674609
# 3     43600  250.000         112  1084.939099
# 4     43602  258.000         115   890.871626
# ...     ...      ...         ...          ...
# 1460  48363    0.000           3     0.321952
# 1461  48370    0.027          19     3.151130
# 1462  48375    0.000           7     0.000000
# 1463  48376    0.000           3     0.000000
# 1464  48395    0.220          14     2.040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
df_dir_bud = data.groupby('director_name')['budget'].max().reset_index() #this is a series so cant perform selective fn so use reset index 
df_dir_bud
# Out:
#                    director_name  budget
# 0                     Adam McKay   100.0
# 1                  Adam Shankman    80.0
# 2    Alejandro González Iñárritu   135.0
# 3                    Alex Proyas   140.0
# 4                Alexander Payne    30.0
# ..                           ...     ...
# 194                   Wes Craven    40.0
# 195            Wolfgang Petersen   175.0
# 196                  Woody Allen    30.0
# 197                  Zack Snyder   250.0
# 198                  Zhang Yimou    94.0
#
# [199 rows x 2 columns]

# %%
df_dir_bud['budget'] >= 100
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 194    False
# 195     True
# 196    False
# 197     True
# 198    False
# Name: budget, Length: 199, dtype: bool

# %%
high_bud_dir = df_dir_bud.loc[df_dir_bud['budget'] >= 100 , 'director_name']
high_bud_dir
# Out:
# 0                       Adam McKay
# 2      Alejandro González Iñárritu
# 3                      Alex Proyas
# 5                   Andrew Adamson
# 10                         Ang Lee
#                   ...
# 187                    Tom Shadyac
# 188                     Tom Tykwer
# 189                     Tony Scott
# 195              Wolfgang Petersen
# 197                    Zack Snyder
# Name: director_name, Length: 85, dtype: object

# %%
df = data
df
# Out:
#        id_x   budget  popularity      revenue  \
# 0     43597  237.000         150  2787.965087
# 1     43598  300.000         139   961.000000
# 2     43599  245.000         107   880.674609
# 3     43600  250.000         112  1084.939099
# 4     43602  258.000         115   890.871626
# ...     ...      ...         ...          ...
# 1460  48363    0.000           3     0.321952
# 1461  48370    0.027          19     3.151130
# 1462  48375    0.000           7     0.000000
# 1463  48376    0.000           3     0.000000
# 1464  48395    0.220          14     2.040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
df.groupby('director_name')

# %%
def sub_avg(x):
    x["budget"] -= x["budget"].mean()
df.groupby('director_name').transform(sub_avg)
# error =  key error  =  cannot find particular index ie budget which is there in table so why ?
#
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'budget'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21492/4132172485.py in <module>
#       1 def sub_avg(x):
#       2     x["budget"] -= x["budget"].mean()
# ...

# %%
def inspect(x):
    print(x)
    print(type(x))
    raise

df.groupby(['director_name']).transform(inspect)

#output shows that the input taken is index (id_x) and not budget and its output is pandas series 
# so transfor works with colom series and not a dataframe 
#so use a col
# Out:
# 176    43882
# 323    44151
# 366    44236
# 505    44503
# 839    45301
# 916    45443
# Name: id_x, dtype: int64
# <class 'pandas.core.series.Series'>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21492/2924994598.py in <module>
#       4     raise
#       5
# ----> 6 df.groupby(['director_name']).transform(inspect)
#       7
#       8 #output shows that the input taken is index (id_x) and not budget and its output is pandas series
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in transform(self, func, engine, engine_kwargs, *args, **kwargs)
#    1355     @Appender(_transform_template)
#    1356     def transform(self, func, *args, engine=None, engine_kwargs=None, **kwargs):
# -> 1357         return self._transform(
#    1358             func, *args, engine=engine, engine_kwargs=engine_kwargs, **kwargs
#    1359         )
# ...

# %%
def sub_avg(x):
    x -= x.mean()
    return x
# df.groupby(['director_name']).transform(inspect)
df['additional_budge'] = df.groupby(['director_name'])["budget"].transform(sub_avg)
# df.groupby(['director_name'])["budget"].transform(sub_avg) == budget col specified 
df['additional_budge']
# Out:
# 0       130.300000
# 1       141.857143
# 2       150.142857
# 3       124.375000
# 4       174.004545
#            ...
# 1460    -47.478947
# 1461    -11.979417
# 1462    -21.700000
# 1463    -10.890909
# 1464    -31.168750
# Name: additional_budge, Length: 1465, dtype: float64

# %%
df
# Out:
#        id_x   budget  popularity      revenue  \
# 0     43597  237.000         150  2787.965087
# 1     43598  300.000         139   961.000000
# 2     43599  245.000         107   880.674609
# 3     43600  250.000         112  1084.939099
# 4     43602  258.000         115   890.871626
# ...     ...      ...         ...          ...
# 1460  48363    0.000           3     0.321952
# 1461  48370    0.027          19     3.151130
# 1462  48375    0.000           7     0.000000
# 1463  48376    0.000           3     0.000000
# 1464  48395    0.220          14     2.040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
# We want to filter the movies whose budget was even higher than the average revenue of the director from his/her other movies
# we can subtract the average revenue of a director from budget col, for each director

# %%
def func(x):
    x["risky"] = x["budget"] - x["revenue"].mean() >= 0
    return x
df_risky = df.groupby("director_name").apply(func)
df_risky
# Out:
#        id_x   budget  popularity      revenue  \
# 0     43597  237.000         150  2787.965087
# 1     43598  300.000         139   961.000000
# 2     43599  245.000         107   880.674609
# 3     43600  250.000         112  1084.939099
# 4     43602  258.000         115   890.871626
# ...     ...      ...         ...          ...
# 1460  48363    0.000           3     0.321952
# 1461  48370    0.027          19     3.151130
# 1462  48375    0.000           7     0.000000
# 1463  48376    0.000           3     0.000000
# 1464  48395    0.220          14     2.040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
df_risky.loc[df_risky["risky"]]
# Out:
#        id_x  budget  popularity      revenue  \
# 7     43608   200.0         107   586.090727
# 12    43614   380.0         135  1045.713802
# 15    43618   200.0          37   310.669540
# 20    43624   209.0          64   303.025485
# 24    43630   210.0           3   459.359555
# ...     ...     ...         ...          ...
# 1347  47224     5.0           7     3.263585
# 1349  47229     5.0           3     4.842699
# 1351  47233     5.0           6     0.000000
# 1356  47263    15.0          10     0.000000
# 1383  47453     3.5           4     0.000000
#
#                                             title  vote_average  vote_count  \
# 7                               Quantum of Solace           6.1        2965
# 12    Pirates of the Caribbean: On Stranger Tides           6.4        4948
# 15                                     Robin Hood           6.2        1398
# 20                                     Battleship           5.5        2114
# ...
