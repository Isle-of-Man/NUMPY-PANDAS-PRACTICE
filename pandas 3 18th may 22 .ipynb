# %%
import pandas as pd
import numpy as np

# %%
# !gdown 1XbB_dq6tH1D16Lg1OiKLXJuitQ8FdcvP
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1XbB_dq6tH1D16Lg1OiKLXJuitQ8FdcvP
# To: C:\Users\Acer\weather.csv
#
#   0%|          | 0.00/12.0k [00:00<?, ?B/s]
# 100%|##########| 12.0k/12.0k [00:00<00:00, 12.0MB/s]

# %%
w = pd.read_csv('weather.csv')

# %%
w.head()
# Out:
#    year  month element       day1       day2       day3       day4       day5  \
# 0  2018      1     max  17.573016  19.796815  22.412495  17.813163  20.165825
# 1  2018      1     min  22.725760  21.007865  17.730792  18.045290  20.766734
# 2  2018      2     max  19.015120  19.261805  17.510713  21.080425  17.915749
# 3  2018      2     min  18.653843  22.818600  21.842673  21.958159  22.523078
# 4  2018      3     max  20.741115  19.704016  17.039811  20.703908  22.714125
#
#         day6       day7  ...      day22      day23      day24      day25  \
# 0  17.060539  22.736134  ...  22.629226  19.013674  17.831558  17.018316
# 1  18.656651  22.607481  ...  21.163491  17.371653  17.194530  18.964190
# 2  19.082145  18.056023  ...  21.254968  20.346324  20.036019  22.926773
# 3  18.535469  19.636158  ...  19.711974  20.586232  18.780840  20.065633
# 4  17.205000  19.079503  ...  19.528963  19.563689  22.658997  22.446357
#
# ...

# %%
#how to restructure the data

# %%
w.shape #rows< col not usual data 
# usually rows> col === also called wide data or rectangular data
# Out:
# (22, 34)

# %%
#convert day col to row Nd change tempmin and max as colos  ==  basically restructuring

# %%
w_m = pd.melt(w ,id_vars=['year' , 'month' , 'element'] , var_name = 'day' , value_name = 'temp')
# id_vars=['year' , 'month' , 'element'] = cols to be kept untouched 
# , var_name = 'day' = col to row variable 
# value_name = 'temp') = name of the value of melted cols

# %%
w_m
# Out:
#      year  month element    day       temp
# 0    2018      1     max   day1  17.573016
# 1    2018      1     min   day1  22.725760
# 2    2018      2     max   day1  19.015120
# 3    2018      2     min   day1  18.653843
# 4    2018      3     max   day1  20.741115
# ..    ...    ...     ...    ...        ...
# 677  2018     10     min  day31  21.691537
# 678  2018     11     max  day31  20.750438
# 679  2018     11     min  day31  18.939767
# 680  2018     12     max  day31  19.648924
# 681  2018     12     min  day31  18.775539
#
# [682 rows x 5 columns]

# %%
#convert element to max and min seperetly 
w_m_pivot = w_m.pivot_table(index = ['year' , 'month' , 'day'],columns = 'element' , values = 'temp').reset_index()

# %%
w_m_pivot
# Out:
# element  year  month    day        max        min
# 0        2018      1   day1  17.573016  22.725760
# 1        2018      1  day10  19.067288  19.931129
# 2        2018      1  day11  19.361002  22.598325
# 3        2018      1  day12  20.982134  17.715137
# 4        2018      1  day13  21.668005  17.940334
# ..        ...    ...    ...        ...        ...
# 336      2018     12   day5  21.375349  20.865535
# 337      2018     12   day6  17.992885  20.310116
# 338      2018     12   day7  19.683359  20.531823
# 339      2018     12   day8  20.477046  19.310346
# 340      2018     12   day9  20.210640  22.820992
#
# [341 rows x 5 columns]

# %%
w_m_pivot.to_csv('w_m_pivot' , sep = ',')

# %%
# uber drive data set

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !gdown 1TL2hWkMWtD1ExVgaQhWP6A2swR8F8cVB
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1TL2hWkMWtD1ExVgaQhWP6A2swR8F8cVB
# To: C:\Users\Acer\UberDrives.csv
#
#   0%|          | 0.00/86.4k [00:00<?, ?B/s]
# 100%|##########| 86.4k/86.4k [00:00<00:00, 1.09MB/s]

# %%
data = pd.read_csv('UberDrives.csv')

# %%
data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
data.shape
# Out:
# (1156, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
data.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
data.drop(1155, axis = 0 , inplace = True )

# %%
data.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*        PURPOSE*
# 1150           Kar?chi     0.7         Meeting
# 1151  Unknown Location     3.9  Temporary Site
# 1152  Unknown Location    16.2         Meeting
# 1153           Gampaha     6.4  Temporary Site
# 1154         Ilukwatta    48.2  Temporary Site

# %%
# check missingnes data.isnull() = gives bool and .sum() will give the count 
data.isnull().sum(axis = 0)
# Out:
# START_DATE*      0
# END_DATE*        0
# CATEGORY*        0
# START*           0
# STOP*            0
# MILES*           0
# PURPOSE*       502
# dtype: int64

# %%
data.describe()
# Out:
#             MILES*
# count  1155.000000
# mean     10.566840
# std      21.579106
# min       0.500000
# 25%       2.900000
# 50%       6.000000
# 75%      10.400000
# max     310.300000

# %%
data.describe(include = 'object')
# Out:
#             START_DATE*        END_DATE* CATEGORY* START* STOP* PURPOSE*
# count              1155             1155      1155   1155  1155      653
# unique             1154             1154         2    177   188       10
# top     6/28/2016 23:34  6/28/2016 23:59  Business   Cary  Cary  Meeting
# freq                  2                2      1078    201   203      187

# %%
# check duplicate 
data.loc[data.duplicated()]
# Out:
#          START_DATE*        END_DATE* CATEGORY*  START* STOP*  MILES* PURPOSE*
# 492  6/28/2016 23:34  6/28/2016 23:59  Business  Durham  Cary     9.9  Meeting

# %%
data.drop_duplicates(inplace = True) #dropped dupli

# %%
data.loc[data.duplicated()] #no more dupli
# Out:
# Empty DataFrame
# Columns: [START_DATE*, END_DATE*, CATEGORY*, START*, STOP*, MILES*, PURPOSE*]
# Index: []

# %%
data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %%
# remove star 
data.columns
# Out:
# Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#        'PURPOSE*'],
#       dtype='object')

# %%
data.columns = [x[:-1] for x in data.columns]

# %%
data
# Out:
#             START_DATE          END_DATE  CATEGORY             START  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# ...

# %%
# how to handle time-stamp data = to_datetime =  convert to date and time but this gives us a series so assign it to a variable
data['START_DATE'] = pd.to_datetime(data['START_DATE'])

# %%
data
# Out:
#               START_DATE          END_DATE  CATEGORY             START  \
# 0    2016-01-01 21:11:00    1/1/2016 21:17  Business       Fort Pierce
# 1    2016-01-02 01:25:00     1/2/2016 1:37  Business       Fort Pierce
# 2    2016-01-02 20:25:00    1/2/2016 20:38  Business       Fort Pierce
# 3    2016-01-05 17:31:00    1/5/2016 17:45  Business       Fort Pierce
# 4    2016-01-06 14:42:00    1/6/2016 15:49  Business       Fort Pierce
# ...                  ...               ...       ...               ...
# 1150 2016-12-31 01:07:00   12/31/2016 1:14  Business           Kar?chi
# 1151 2016-12-31 13:24:00  12/31/2016 13:42  Business           Kar?chi
# 1152 2016-12-31 15:03:00  12/31/2016 15:38  Business  Unknown Location
# 1153 2016-12-31 21:32:00  12/31/2016 21:50  Business        Katunayake
# 1154 2016-12-31 22:08:00  12/31/2016 23:51  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# 0          Fort Pierce    5.1   Meal/Entertain
# ...

# %%
data['END_DATE'] = pd.to_datetime(data['END_DATE'])
# data["'END_DATE'"]= data["END_DATE"].astype("datetime64")

# %%
data
# Out:
#               START_DATE            END_DATE  CATEGORY             START  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Kar?chi
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# ...

# %%
data.info()
#  START_DATE  1154 non-null   datetime64[ns] = changed to this datetime format from object 
#  END_DATE    1154 non-null   datetime64[ns]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1150 entries, 0 to 1154
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1150 non-null   datetime64[ns]
#  1   END_DATE    1150 non-null   datetime64[ns]
#  2   CATEGORY    1150 non-null   object
#  3   START       1150 non-null   object
#  4   STOP        1150 non-null   object
#  5   MILES       1150 non-null   float64
#  6   PURPOSE     652 non-null    object
#  7   'END_DATE'  1150 non-null   datetime64[ns]
# dtypes: datetime64[ns](3), float64(1), object(4)
# memory usage: 113.1+ KB

# %%
# how will it handle if it has invalid format ?

# %%
# Cross Check for rows where start timestamp and end timestamp are same ?
data.loc[data['START_DATE'] == data['END_DATE']]
# Out:
#              START_DATE            END_DATE  CATEGORY             START  \
# 751 2016-09-06 17:49:00 2016-09-06 17:49:00  Business  Unknown Location
# 761 2016-09-16 07:08:00 2016-09-16 07:08:00  Business  Unknown Location
# 798 2016-10-08 15:03:00 2016-10-08 15:03:00  Business           Karachi
# 807 2016-10-13 13:02:00 2016-10-13 13:02:00  Business         Islamabad
#
#                  STOP  MILES PURPOSE
# 751  Unknown Location   69.1     NaN
# 761  Unknown Location    1.6     NaN
# 798           Karachi    3.6     NaN
# 807         Islamabad    0.7     NaN

# %%
data.drop(data.index[[751,761,798,807]],inplace = True)

# %%
data
# Out:
#               START_DATE            END_DATE  CATEGORY             START  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Kar?chi
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# ...

# %%
data.shape
# Out:
# (1150, 7)

# %%
ts = data['START_DATE'][0] #could extract values by saving

# %%
ts
# Out:
# Timestamp('2016-01-01 21:11:00')

# %%
ts.year
# Out:
# 2016

# %%
ts.month
# Out:
# 1

# %%
ts.day
# Out:
# 1

# %%
ts.month_name()
# Out:
# 'January'

# %%
ts.day_name()
# Out:
# 'Friday'

# %%
ts.hour
# Out:
# 21

# %%
# Out:
# 0       2022
# 1       2022
# 2       2022
# 3       2022
# 4       2022
#         ...
# 1150    2022
# 1151    2022
# 1152    2022
# 1153    2022
# 1154    2022
# Name: END_DATE, Length: 1150, dtype: int64

# %%
data['END_DATE']
# since this is a col we need to work on the whole col
# Out:
# 0      1970-01-01 00:00:00.000002022
# 1      1970-01-01 00:00:00.000002022
# 2      1970-01-01 00:00:00.000002022
# 3      1970-01-01 00:00:00.000002022
# 4      1970-01-01 00:00:00.000002022
#                     ...
# 1150   1970-01-01 00:00:00.000002022
# 1151   1970-01-01 00:00:00.000002022
# 1152   1970-01-01 00:00:00.000002022
# 1153   1970-01-01 00:00:00.000002022
# 1154   1970-01-01 00:00:00.000002022
# Name: END_DATE, Length: 1150, dtype: datetime64[ns]

# %%
# extract year 
data['END_DATE'].dt.year
# Out:
# 0       1970
# 1       1970
# 2       1970
# 3       1970
# 4       1970
#         ...
# 1150    1970
# 1151    1970
# 1152    1970
# 1153    1970
# 1154    1970
# Name: END_DATE, Length: 1150, dtype: int64

# %%
data['END_DATE'].dt.month_name() 
# can be used for feature transformation 
# why month name and day name is a attribute ==  because these are extracting values which are not present in the data
# Out:
# 0        January
# 1        January
# 2        January
# 3        January
# 4        January
#           ...
# 1150    December
# 1151    December
# 1152    December
# 1153    December
# 1154    December
# Name: END_DATE, Length: 1150, dtype: object

# %%
# What is the shortest journey made?
# What is the longest journey made?
# What is the average journey made?
# How many years of data do we have?

# %%
data.describe().reset_index()
# Out:
#    index        MILES
# 0  count  1150.000000
# 1   mean    10.584609
# 2    std    21.623241
# 3    min     0.500000
# 4    25%     2.900000
# 5    50%     6.000000
# 6    75%    10.400000
# 7    max   310.300000

# %%
data
# Out:
#               START_DATE            END_DATE  CATEGORY             START  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Kar?chi
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
#
#                   STOP  MILES          PURPOSE
# ...

# %%
df = pd.DataFrame({'Date':["2015-12-06", "2011-12-27", "2015-09-07", "2012-12-21", "2020-02-13", "2015-06-09"], 'RID':[498, 721, 375, 464, 813, 853], 'Phy':[22, 45, 1, 65, 22, 17], 'Chem':[52, 56, 32, 50, 24, 61], 'Math':[63, 37, 68, 62, 43 ,42]})

# %%
df
# Out:
#          Date  RID  Phy  Chem  Math
# 0  2015-12-06  498   22    52    63
# 1  2011-12-27  721   45    56    37
# 2  2015-09-07  375    1    32    68
# 3  2012-12-21  464   65    50    62
# 4  2020-02-13  813   22    24    43
# 5  2015-06-09  853   17    61    42

# %%
df.shape
# Out:
# (6, 5)

# %%
df.describe()
# Out:
#               RID        Phy       Chem       Math
# count    6.000000   6.000000   6.000000   6.000000
# mean   620.666667  28.666667  45.833333  52.500000
# std    200.490066  22.703891  14.538455  13.277801
# min    375.000000   1.000000  24.000000  37.000000
# 25%    472.500000  18.250000  36.500000  42.250000
# 50%    609.500000  22.000000  51.000000  52.500000
# 75%    790.000000  39.250000  55.000000  62.750000
# max    853.000000  65.000000  61.000000  68.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    6 non-null      object
#  1   RID     6 non-null      int64
#  2   Phy     6 non-null      int64
#  3   Chem    6 non-null      int64
#  4   Math    6 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 368.0+ bytes

# %%
# pd.melt(df, id_vars = ['Phy','Chem','Math'] , var_name = 'Date' , value_name = 'temp')
# Out:
#     Phy  Chem  Math  Date        temp
# 0    22    52    63  Date  2015-12-06
# 1    45    56    37  Date  2011-12-27
# 2     1    32    68  Date  2015-09-07
# 3    65    50    62  Date  2012-12-21
# 4    22    24    43  Date  2020-02-13
# 5    17    61    42  Date  2015-06-09
# 6    22    52    63   RID         498
# 7    45    56    37   RID         721
# 8     1    32    68   RID         375
# 9    65    50    62   RID         464
# 10   22    24    43   RID         813
# 11   17    61    42   RID         853

# %%
q1 = pd.DataFrame({
  "Accessories": ["Laptop", "Laptop", "Ipad", "Ipad", "Tablet", "Laptop"],
  "customer": ["Andrew", "Andrew", "Tom", "Andrew", "Tobey", "Peter"],
  "quantity": [1, 2, 2, 3, 1, 2],
})

# %%
q1
# Out:
#   Accessories customer  quantity
# 0      Laptop   Andrew         1
# 1      Laptop   Andrew         2
# 2        Ipad      Tom         2
# 3        Ipad   Andrew         3
# 4      Tablet    Tobey         1
# 5      Laptop    Peter         2

# %%
q1.groupby(['Accessories', 'customer']).quantity.sum().unstack()
# Out:
# customer     Andrew  Peter  Tobey  Tom
# Accessories
# Ipad            3.0    NaN    NaN  2.0
# Laptop          3.0    2.0    NaN  NaN
# Tablet          NaN    NaN    1.0  NaN

# %%
q1.pivot_table(index="Accessories", columns="customer", values="quantity", aggfunc=np.sum)
# Out:
# customer     Andrew  Peter  Tobey  Tom
# Accessories
# Ipad            3.0    NaN    NaN  2.0
# Laptop          3.0    2.0    NaN  NaN
# Tablet          NaN    NaN    1.0  NaN

# %%
q1.pivot_table(index="Accessories", columns="customer", values="quantity", aggfunc=np.sum, fill_value=0)
# Out:
# customer     Andrew  Peter  Tobey  Tom
# Accessories
# Ipad              3      0      0    2
# Laptop            3      2      0    0
# Tablet            0      0      1    0

# %%
q2 = pd.DataFrame({
 "A":['tst1','tst2','tst3','tst3'],
 "B":[5, 6, 7, 8],
 "C":[9, 10, 11 ,12],
 "D":[13, 14, 15, 16]
})

# %%
q2
# The task here is to create a dataframe where the 
# first column is the test number, 
# the second column is the student's name and the
# third column consists of the scores of the students in that particular test.
# Out:
#       A  B   C   D
# 0  tst1  5   9  13
# 1  tst2  6  10  14
# 2  tst3  7  11  15
# 3  tst3  8  12  16

# %%
q2.melt(id_vars =['A'], value_vars = ['B', 'C', 'D'],var_name ='St_name', value_name ='Scores')

# id_vars=['year' , 'month' , 'element'] = cols to be kept untouched 
# var_name = 'day' = col to row variable 
# value_name = 'temp') = name of the value of melted cols
# Out:
#        A St_name  Scores
# 0   tst1       B       5
# 1   tst2       B       6
# 2   tst3       B       7
# 3   tst3       B       8
# 4   tst1       C       9
# 5   tst2       C      10
# 6   tst3       C      11
# 7   tst3       C      12
# 8   tst1       D      13
# 9   tst2       D      14
# 10  tst3       D      15
# 11  tst3       D      16

# %%
q2.melt(id_vars =['A'], value_vars = np.array(q2.columns)[1:] ,var_name ='St_name', value_name ='Scores')
# Out:
#        A St_name  Scores
# 0   tst1       B       5
# 1   tst2       B       6
# 2   tst3       B       7
# 3   tst3       B       8
# 4   tst1       C       9
# 5   tst2       C      10
# 6   tst3       C      11
# 7   tst3       C      12
# 8   tst1       D      13
# 9   tst2       D      14
# 10  tst3       D      15
# 11  tst3       D      16

# %%
# !gdown "C:\Users\Acer\Downloads\sales_dataset.csv"

# %%
q4 = pd.read_excel (r"C:\Users\Acer\Downloads\sales_dataset.csv", sheet_name='sales_dataset')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19412/1887753496.py in <module>
# ----> 1 q4 = pd.read_excel (r"C:\Users\Acer\Downloads\sales_dataset.csv", sheet_name='sales_dataset')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
# ...

# %%
q4 = pd.read_csv(r"C:\Users\Acer\Downloads\sales_dataset.csv" , encoding = "Latin-1")

# %%
q4
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
q4.describe()
# Out:
#            Quantity         Price    Customer ID
# count  1.067371e+06  1.067371e+06  824364.000000
# mean   9.938898e+00  4.649388e+00   15324.638504
# std    1.727058e+02  1.235531e+02    1697.464450
# min   -8.099500e+04 -5.359436e+04   12346.000000
# 25%    1.000000e+00  1.250000e+00   13975.000000
# 50%    3.000000e+00  2.100000e+00   15255.000000
# 75%    1.000000e+01  4.150000e+00   16797.000000
# max    8.099500e+04  3.897000e+04   18287.000000

# %%
q4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067371 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1067371 non-null  object
#  1   StockCode    1067371 non-null  object
#  2   Description  1062989 non-null  object
#  3   Quantity     1067371 non-null  int64
#  4   InvoiceDate  1067371 non-null  object
#  5   Price        1067371 non-null  float64
#  6   Customer ID  824364 non-null   float64
#  7   Country      1067371 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 65.1+ MB

# %%
q4.tail()
# Out:
#         Invoice StockCode                      Description  Quantity  \
# 1067366  581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138    BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                          POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID Country
# 1067366  2011-12-09 12:50:00   2.10      12680.0  France
# 1067367  2011-12-09 12:50:00   4.15      12680.0  France
# 1067368  2011-12-09 12:50:00   4.15      12680.0  France
# 1067369  2011-12-09 12:50:00   4.95      12680.0  France
# 1067370  2011-12-09 12:50:00  18.00      12680.0  France

# %%
q4.loc[q4['Description'] == 'BLACK AND WHITE PAISLEY FLOWER MUG'].count()
# Out:
# Invoice        34
# StockCode      34
# Description    34
# Quantity       34
# InvoiceDate    34
# Price          34
# Customer ID    19
# Country        34
# dtype: int64

# %%
q4.loc[q4['Description'] == 'WHITE HANGING HEART T-LIGHT HOLDER'].count()
# Out:
# Invoice        5918
# StockCode      5918
# Description    5918
# Quantity       5918
# InvoiceDate    5918
# Price          5918
# Customer ID    5315
# Country        5918
# dtype: int64

# %%
mod=q4.groupby('Description').sum()

# %%
mod
# Out:
#                                      Quantity   Price  Customer ID  purchase
# Description
#   DOORMAT UNION JACK GUNS AND ROSES       179  460.64     842345.0   1206.81
#  3 STRIPEY MICE FELTCRAFT                 690  292.82    1791538.0   1340.08
#  4 PURPLE FLOCK DINNER CANDLES            351  154.95     901806.0    588.91
#  50'S CHRISTMAS GIFT BAG LARGE           1913  185.28    1687133.0   2341.13
#  ANIMAL STICKERS                          385    2.52     182720.0     80.85
# ...                                       ...     ...          ...       ...
# wrongly marked carton 22804              -256    0.00          0.0      0.00
# wrongly marked. 23343 in box            -3100    0.00          0.0      0.00
# wrongly sold (22719) barcode              170    0.00          0.0      0.00
# wrongly sold as sets                     -600    0.00          0.0      0.00
# wrongly sold sets                        -975    0.00          0.0      0.00
#
# [5698 rows x 4 columns]

# %%
mod[mod['Quantity']==max(mod['Quantity'])]
# Out:
#                                    Quantity   Price  Customer ID
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS    108545  298.18   14628933.0

# %%
q4
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
q4['purchase'] = q4['Price'] * q4['Quantity']

# %%
q4
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country  purchase
# ...

# %%
q4[q4['purchase']==max(q4['purchase'])]
# Out:
#         Invoice StockCode                  Description  Quantity  \
# 1065882  581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
#
#                  InvoiceDate  Price  Customer ID         Country  purchase
# 1065882  2011-12-09 09:15:00   2.08      16446.0  United Kingdom  168469.6

# %%
# The number of unique customers who made a purchase on 22 June 2011 is?
# df['InvoiceDate']=pd.to_datetime(df['InvoiceDate'])
# df['Date']=pd.to_datetime(df['InvoiceDate'].dt.date)

# ans=df[df['Date']=='2011-06-22']
# ans['Customer ID'].nunique()

# %%
q4['InvoiceDate'] = pd.to_datetime(q4['InvoiceDate'])

# %%
q4['InvoiceDate']
# Out:
# 0         2009-12-01 07:45:00
# 1         2009-12-01 07:45:00
# 2         2009-12-01 07:45:00
# 3         2009-12-01 07:45:00
# 4         2009-12-01 07:45:00
#                   ...
# 1067366   2011-12-09 12:50:00
# 1067367   2011-12-09 12:50:00
# 1067368   2011-12-09 12:50:00
# 1067369   2011-12-09 12:50:00
# 1067370   2011-12-09 12:50:00
# Name: InvoiceDate, Length: 1067371, dtype: datetime64[ns]

# %%
q4['date'] = pd.to_datetime(q4['InvoiceDate'].dt.date)

# %%
count = q4[q4['date'] == '2011-06-22']

# %%
count
# Out:
#        Invoice StockCode                    Description  Quantity  \
# 761424  557667     22730     ALARM CLOCK BAKELIKE IVORY        12
# 761425  557667    85232D  SET/3 DECOUPAGE STACKING TINS         3
# 761426  557667     22727      ALARM CLOCK BAKELIKE RED         24
# 761427  557667     23084             RABBIT NIGHT LIGHT        24
# 761428  557667     22726     ALARM CLOCK BAKELIKE GREEN        24
# ...        ...       ...                            ...       ...
# 762436  557793     82567      AIRLINE LOUNGE,METAL SIGN         1
# 762437  557793     21172              PARTY METAL SIGN          2
# 762438  557793     22426         ENAMEL WASH BOWL CREAM         1
# 762439  557793     22429     ENAMEL MEASURING JUG CREAM         1
# 762440  557793     22425          ENAMEL COLANDER CREAM         1
#
#                InvoiceDate  Price  Customer ID         Country  purchase  \
# 761424 2011-06-22 08:30:00   3.75      15606.0  United Kingdom     45.00
# ...

# %%
count['Customer ID'].nunique()
# Out:
# 57

# %%
# my method 
q4.loc[q4['InvoiceDate'].astype(str).str.contains('2011-06-22', case = False)].nunique()
# Out:
# Invoice         68
# StockCode      652
# Description    649
# Quantity        47
# InvoiceDate     63
# Price           76
# Customer ID     57
# Country          8
# purchase       278
# date             1
# dtype: int64

# %%
# Which date has the highest sales(total price) in France?

# %%
q4['sales'] = q4['Price'] * q4['Quantity']

# %%
q4
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country   sales
# ...

# %%
# grouping  by france
france = q4.loc[q4.Country == 'France']

# %%
q4['InvoiceDate'] = pd.to_datetime(q4['InvoiceDate'])

# %%
ans=max(q4.loc[q4.Country == 'France','sales'])
q4[q4['sales']==ans]
# Out:
#        Invoice StockCode Description  Quantity         InvoiceDate    Price  \
# 947835  573077         M      Manual         1 2011-10-27 14:13:00  4161.06
# 947838  573080         M      Manual         1 2011-10-27 14:20:00  4161.06
#
#         Customer ID Country    sales
# 947835      12536.0  France  4161.06
# 947838      12536.0  France  4161.06

# %%
q4[q4['InvoiceDate'] == '2010-08-09']
# Out:
# Empty DataFrame
# Columns: [Invoice, StockCode, Description, Quantity, InvoiceDate, Price, Customer ID, Country, sales]
# Index: []

# %%
france.groupby('sales')['InvoiceDate'].max()
# Out:
# sales
# -8322.12    2011-10-27 14:15:00
# -1653.12    2010-09-28 11:02:00
# -1136.30    2011-04-05 09:46:00
# -1055.75    2010-09-02 09:31:00
# -911.04     2010-09-28 11:02:00
#                    ...
#  1136.30    2011-04-05 09:45:00
#  1632.48    2011-10-28 07:39:00
#  1653.12    2010-08-09 13:10:00
#  3610.50    2010-07-29 12:29:00
#  4161.06    2011-10-27 14:20:00
# Name: InvoiceDate, Length: 802, dtype: object

# %%
ans
# Out:
# Country
# Australia                 1718.40
# Austria                    360.00
# Bahrain                    205.74
# Belgium                   1508.65
# Bermuda                    241.92
# Brazil                     175.20
# Canada                     550.94
# Channel Islands            885.00
# Cyprus                     350.40
# Czech Republic              70.80
# Denmark                   3630.80
# EIRE                      2736.16
# European Community          60.00
# Finland                    551.20
# France                    4161.06
# Germany                    876.00
# Greece                     229.50
# Hong Kong                 2653.95
# Iceland                    249.60
# Israel                     350.40
# Italy                      300.00
# Japan                     3794.40
# Korea                      100.80
# Lebanon                    153.00
# Lithuania                  122.40
# Malta                     1868.56
# Netherlands               4992.00
# ...

# %%
# The number of unique StockCode in the United Kingdom according to Sales_dataset?
q4
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                 InvoiceDate  Price  Customer ID         Country   sales
# ...

# %%
q8ans=(q4.loc[q4.Country == 'United Kingdom','StockCode']).nunique()

# %%
q8ans
# Out:
# 5303

# %%
q11 = pd.DataFrame({'Date':["2015-12-06", "2011-12-27", "2015-09-07", "2012-12-21", "2020-02-13", "2015-06-09"], 'RID':[498, 721, 375, 464, 813, 853], 'Phy':[22, 45, 1, 65, 22, 17], 'Chem':[52, 56, 32, 50, 24, 61], 'Math':[63, 37, 68, 62, 43 ,42]})

# %%
q11
# Out:
#          Date  RID  Phy  Chem  Math
# 0  2015-12-06  498   22    52    63
# 1  2011-12-27  721   45    56    37
# 2  2015-09-07  375    1    32    68
# 3  2012-12-21  464   65    50    62
# 4  2020-02-13  813   22    24    43
# 5  2015-06-09  853   17    61    42
